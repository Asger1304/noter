# %%
import nashpy as nash
import numpy as np

# %%
A = np.array([[2, 1], [0, 6]])
B = np.array([[2, 3] ,[4, 0]])

game = nash.Game(A, B)

equilibria = list(game.support_enumeration())
for eq in equilibria:
    print(eq)
# Out:
# (array([0.8, 0.2]), array([0.71428571, 0.28571429]))
